# %%
import pandas as pd

# %%
df_financials = pd.read_csv("/Users/annita/Desktop/Thesis/tables/financials/moodys_financials.csv")

# %%
print("Shape:")
print(df_financials.shape)

print("\nColumns:")
print(df_financials.columns.tolist())

print("\nData types:")
print(df_financials.dtypes)

print("\nSample:")
df_financials.head()
# Out:
# Shape:
# (17390, 52)
#
# Columns:
# ['moodys_bvd_id', 'moodys_company_name', 'Status', 'Implied_rating - original', 'Implied_rating', 'risk_level', 'output_text', 'Financial_level', 'closing_year', 'closing_date', 'Number_of_months', 'Net_Salesth_DKK', 'Operating_revenue_Turnover_th_DKK', 'Gross_profit_th_DKK', 'EBIT_th_DKK', 'Net_income_th_DKK', 'Interest_paid_th_DKK', 'EBITDA_th_DKK', 'Costs_of_goods_soldth_DKK', 'Total_assets_th_DKK', 'Non-current_assetsth_DKK', 'Current_assets_th_DKK', 'Cash_and_cash_equivalent_th_DKK', "Total_shareholders'_funds_and_liabilitiesth_DKK", 'Long_term_debtth_DKK', 'Other_current_assetsth_DKK', 'Shareholders_funds_th_DKK', 'Current_liabilities_th_DKK', 'Non_current_liabilities_th_DKK', 'Other_non_current_liabilitiesth_DKK', 'Other_current_liabilitiesth_DKK', 'Working_capital_th_DKK', 'Profit_margin', 'Gross_margin', 'EBITDA_margin', 'EBIT_margin', 'Current_ratio', 'Gearing', 'Cash_ratio', 'Long_term_Gearing', 'Short_term_Gearing', 'Total_liabilities_Equity_ratio', 'Long_term_liabilities_Equity_ratio', 'Short_term_liabilities_Equity_ratio', 'Interest_coverage_ratio', 'Solvency_ratio_Asset_based', 'Debt_Asset_ratio', 'ROE_using_Net_income', 'ROA_using_Net_income', 'Net_assets_turnover', 'Number_of_employees', 'created_at_utc']
#
# Data types:
# moodys_bvd_id                                          str
# moodys_company_name                                    str
# Status                                                 str
# Implied_rating - original                              str
# Implied_rating                                         str
# risk_level                                             str
# output_text                                            str
# Financial_level                                        str
# closing_year                                       float64
# closing_date                                           str
# Number_of_months                                   float64
# Net_Salesth_DKK                                    float64
# Operating_revenue_Turnover_th_DKK                  float64
# Gross_profit_th_DKK                                float64
# EBIT_th_DKK                                        float64
# Net_income_th_DKK                                  float64
# Interest_paid_th_DKK                               float64
# EBITDA_th_DKK                                      float64
# Costs_of_goods_soldth_DKK                          float64
# Total_assets_th_DKK                                float64
# Non-current_assetsth_DKK                           float64
# Current_assets_th_DKK                              float64
# Cash_and_cash_equivalent_th_DKK                    float64
# Total_shareholders'_funds_and_liabilitiesth_DKK    float64
# Long_term_debtth_DKK                               float64
# Other_current_assetsth_DKK                         float64
# Shareholders_funds_th_DKK                          float64
# Current_liabilities_th_DKK                         float64
# Non_current_liabilities_th_DKK                     float64
# Other_non_current_liabilitiesth_DKK                float64
# Other_current_liabilitiesth_DKK                    float64
# Working_capital_th_DKK                             float64
# Profit_margin                                      float64
# Gross_margin                                       float64
# EBITDA_margin                                      float64
# EBIT_margin                                        float64
# Current_ratio                                      float64
# Gearing                                            float64
# Cash_ratio                                         float64
# Long_term_Gearing                                  float64
# Short_term_Gearing                                 float64
# Total_liabilities_Equity_ratio                     float64
# Long_term_liabilities_Equity_ratio                 float64
# Short_term_liabilities_Equity_ratio                float64
# Interest_coverage_ratio                            float64
# Solvency_ratio_Asset_based                         float64
# Debt_Asset_ratio                                   float64
# ROE_using_Net_income                               float64
# ROA_using_Net_income                               float64
# Net_assets_turnover                                float64
# Number_of_employees                                float64
# created_at_utc                                         str
# dtype: object
#
# Sample:
#     moodys_bvd_id                  moodys_company_name  Status  \
# 0      GB03898252            THE Turner Agency Limited  Active
# 1     FR900421140                               Kliper  Active
# 2      GB11779532                    67 Health Limited  Active
# 3      GB11429590          Caristo Diagnostics Limited  Active
# 4  MXCTS160922QLA  Corporate Travel Services Worldwide  Active
#
#   Implied_rating - original Implied_rating     risk_level  \
# 0                       Ba3             Ba   Take caution
# 1                        B2              B  Do not source
# 2                       Ba1             Ba   Take caution
# 3                      Baa3            Baa   Take caution
# 4                        B1              B  Do not source
#
#                                          output_text      Financial_level  \
# 0  Use caution. Input from outdated and/or partia...                  NaN
# 1  Sourcing exclusion recommended. Input from out...                  NaN
# 2  Use caution. Input from outdated and/or partia...                  NaN
# 3  Use caution. Input from outdated and/or partia...                  NaN
# 4  Sourcing exclusion recommended. Mitigation act...  High financial risk
#
#    closing_year closing_date  ...  Long_term_liabilities_Equity_ratio  \
# 0        2023.0   2023-12-31  ...                            1.773269
# 1        2022.0   2022-12-31  ...                       -10508.485250
# 2        2022.0   2022-12-31  ...                            0.115574
# 3        2022.0   2022-12-31  ...                            0.000000
# 4        2025.0   2025-03-31  ...                           14.500631
#
#    Short_term_liabilities_Equity_ratio  Interest_coverage_ratio  \
# 0                           226.829799                      NaN
# 1                        -16104.342062                      NaN
# 2                            88.746533                      NaN
# 3                            35.170227                      NaN
# 4                           126.422891                      NaN
#
#    Solvency_ratio_Asset_based  Debt_Asset_ratio  ROE_using_Net_income  \
# 0                      30.432          0.000000                   NaN
# 1                      -0.377          0.468776                   NaN
# 2                      52.949          0.038929                   NaN
# 3                      73.981               NaN                   NaN
# 4                      41.507          0.000000                 1.412
#
#    ROA_using_Net_income  Net_assets_turnover  Number_of_employees  \
# 0                   NaN                  NaN                 31.0
# 1                   NaN                  NaN                  NaN
# 2                   NaN                  NaN                  9.0
# 3                   NaN                  NaN                 33.0
# 4                 2.344                3.641                552.0
#
#                      created_at_utc
# 0  2026-03-12 11:47:28.083189+00:00
# 1  2026-03-12 11:47:28.083189+00:00
# 2  2026-03-12 11:47:28.083189+00:00
# 3  2026-03-12 11:47:28.083189+00:00
# 4  2026-03-12 11:47:28.083189+00:00
#
# [5 rows x 52 columns]

# %% [markdown]
# one row = one Moody’s company in one closing year

# %%
dup = df_financials.duplicated(
    ["moodys_bvd_id", "closing_year"]
).sum()

print("Duplicate company-year rows:", dup)
# Out:
# Duplicate company-year rows: 12996

# %%
print(
    "Unique companies:",
    df_financials["moodys_bvd_id"].nunique()
)
# Out:
# Unique companies: 1989

# %%
print(
    df_financials["closing_year"]
    .sort_values()
    .unique()
)
# Out:
# [1997. 2000. 2001. 2002. 2003. 2004. 2005. 2006. 2007. 2008. 2009. 2010.
#  2011. 2012. 2013. 2014. 2015. 2016. 2017. 2018. 2019. 2020. 2021. 2022.
#  2023. 2024. 2025. 2026.   nan]

# %%
df_financials.head()
# Out:
#     moodys_bvd_id                  moodys_company_name  Status  \
# 0      GB03898252            THE Turner Agency Limited  Active
# 1     FR900421140                               Kliper  Active
# 2      GB11779532                    67 Health Limited  Active
# 3      GB11429590          Caristo Diagnostics Limited  Active
# 4  MXCTS160922QLA  Corporate Travel Services Worldwide  Active
#
#   Implied_rating - original Implied_rating     risk_level  \
# 0                       Ba3             Ba   Take caution
# 1                        B2              B  Do not source
# 2                       Ba1             Ba   Take caution
# 3                      Baa3            Baa   Take caution
# 4                        B1              B  Do not source
#
#                                          output_text      Financial_level  \
# 0  Use caution. Input from outdated and/or partia...                  NaN
# 1  Sourcing exclusion recommended. Input from out...                  NaN
# 2  Use caution. Input from outdated and/or partia...                  NaN
# 3  Use caution. Input from outdated and/or partia...                  NaN
# 4  Sourcing exclusion recommended. Mitigation act...  High financial risk
#
#    closing_year closing_date  ...  Long_term_liabilities_Equity_ratio  \
# 0        2023.0   2023-12-31  ...                            1.773269
# 1        2022.0   2022-12-31  ...                       -10508.485250
# 2        2022.0   2022-12-31  ...                            0.115574
# 3        2022.0   2022-12-31  ...                            0.000000
# 4        2025.0   2025-03-31  ...                           14.500631
#
#    Short_term_liabilities_Equity_ratio  Interest_coverage_ratio  \
# 0                           226.829799                      NaN
# 1                        -16104.342062                      NaN
# 2                            88.746533                      NaN
# 3                            35.170227                      NaN
# 4                           126.422891                      NaN
#
#    Solvency_ratio_Asset_based  Debt_Asset_ratio  ROE_using_Net_income  \
# 0                      30.432          0.000000                   NaN
# 1                      -0.377          0.468776                   NaN
# 2                      52.949          0.038929                   NaN
# 3                      73.981               NaN                   NaN
# 4                      41.507          0.000000                 1.412
#
#    ROA_using_Net_income  Net_assets_turnover  Number_of_employees  \
# 0                   NaN                  NaN                 31.0
# 1                   NaN                  NaN                  NaN
# 2                   NaN                  NaN                  9.0
# 3                   NaN                  NaN                 33.0
# 4                 2.344                3.641                552.0
#
#                      created_at_utc
# 0  2026-03-12 11:47:28.083189+00:00
# 1  2026-03-12 11:47:28.083189+00:00
# 2  2026-03-12 11:47:28.083189+00:00
# 3  2026-03-12 11:47:28.083189+00:00
# 4  2026-03-12 11:47:28.083189+00:00
#
# [5 rows x 52 columns]

# %%
company_id = df_financials["moodys_bvd_id"].iloc[0]
print(company_id)

df_company = (
    df_financials[
        df_financials["moodys_bvd_id"] == company_id
    ]
    .sort_values(["closing_year", "created_at_utc"])
)

df_company[
    [
        "moodys_bvd_id",
        "closing_year",
        "risk_level",
        "Implied_rating",
        "created_at_utc"
    ]
]
# Out:
# GB03898252
#       moodys_bvd_id  closing_year    risk_level Implied_rating  \
# 13208    GB03898252        2023.0  Take caution             Ba
# 14199    GB03898252        2023.0  Take caution             Ba
# 0        GB03898252        2023.0  Take caution             Ba
# 108      GB03898252        2023.0  Take caution             Ba
# 4396     GB03898252        2023.0  Take caution             Ba
# 4504     GB03898252        2023.0  Take caution             Ba
# 8792     GB03898252        2023.0  Take caution             Ba
# 8900     GB03898252        2023.0  Take caution             Ba
# 14191    GB03898252        2024.0  Take caution             Ba
# 118      GB03898252        2024.0  Take caution             Ba
# 4514     GB03898252        2024.0  Take caution             Ba
# 8910     GB03898252        2024.0  Take caution             Ba
#
#                          created_at_utc
# 13208  2026-03-05 09:02:26.421112+00:00
# 14199  2026-03-05 09:02:26.421112+00:00
# 0      2026-03-12 11:47:28.083189+00:00
# 108    2026-03-12 11:47:28.083189+00:00
# 4396   2026-03-12 12:03:33.903081+00:00
# 4504   2026-03-12 12:03:33.903081+00:00
# 8792   2026-03-12 15:07:22.230528+00:00
# 8900   2026-03-12 15:07:22.230528+00:00
# 14191  2026-03-05 09:02:26.421112+00:00
# 118    2026-03-12 11:47:28.083189+00:00
# 4514   2026-03-12 12:03:33.903081+00:00
# 8910   2026-03-12 15:07:22.230528+00:00

# %%
dup_examples = (
    df_financials
    .loc[
        df_financials.duplicated(
            ["moodys_bvd_id", "closing_year"],
            keep=False
        )
    ]
    .sort_values(
        ["moodys_bvd_id", "closing_year", "created_at_utc"]
    )
)

dup_examples.head(20)
# Out:
#       moodys_bvd_id                   moodys_company_name  Status  \
# 16565  AE0001327927                    Rever Events L.L.C  Active
# 3508   AE0001327927                    Rever Events L.L.C  Active
# 7904   AE0001327927                    Rever Events L.L.C  Active
# 12300  AE0001327927                    Rever Events L.L.C  Active
# 17219  AE0001327927                    Rever Events L.L.C  Active
# 4212   AE0001327927                    Rever Events L.L.C  Active
# 8608   AE0001327927                    Rever Events L.L.C  Active
# 13004  AE0001327927                    Rever Events L.L.C  Active
# 17181  AE0043368774  Fifth Element Event Management L.L.C  Active
# 4233   AE0043368774  Fifth Element Event Management L.L.C  Active
# 8629   AE0043368774  Fifth Element Event Management L.L.C  Active
# 13025  AE0043368774  Fifth Element Event Management L.L.C  Active
# 16564  AE0074958188       Curis Health Studies & Research  Active
# 3507   AE0074958188       Curis Health Studies & Research  Active
# 7903   AE0074958188       Curis Health Studies & Research  Active
# 12299  AE0074958188       Curis Health Studies & Research  Active
# 17218  AE0074958188       Curis Health Studies & Research  Active
# 4211   AE0074958188       Curis Health Studies & Research  Active
# 8607   AE0074958188       Curis Health Studies & Research  Active
# 13003  AE0074958188       Curis Health Studies & Research  Active
#
#       Implied_rating - original Implied_rating    risk_level  \
# 16565                       Ba2             Ba  Take caution
# 3508                        Ba2             Ba  Take caution
# 7904                        Ba2             Ba  Take caution
# 12300                       Ba2             Ba  Take caution
# 17219                       Ba2             Ba  Take caution
# 4212                        Ba2             Ba  Take caution
# 8608                        Ba2             Ba  Take caution
# 13004                       Ba2             Ba  Take caution
# 17181                       Ba2             Ba  Take caution
# 4233                        Ba2             Ba  Take caution
# 8629                        Ba2             Ba  Take caution
# 13025                       Ba2             Ba  Take caution
# 16564                       Ba2             Ba  Take caution
# 3507                        Ba2             Ba  Take caution
# 7903                        Ba2             Ba  Take caution
# 12299                       Ba2             Ba  Take caution
# 17218                       Ba2             Ba  Take caution
# 4211                        Ba2             Ba  Take caution
# 8607                        Ba2             Ba  Take caution
# 13003                       Ba2             Ba  Take caution
#
#                                              output_text Financial_level  \
# 16565  Use caution. Input from outdated and/or partia...             NaN
# 3508   Use caution. Input from outdated and/or partia...             NaN
# 7904   Use caution. Input from outdated and/or partia...             NaN
# 12300  Use caution. Input from outdated and/or partia...             NaN
# 17219  Use caution. Input from outdated and/or partia...             NaN
# 4212   Use caution. Input from outdated and/or partia...             NaN
# 8608   Use caution. Input from outdated and/or partia...             NaN
# 13004  Use caution. Input from outdated and/or partia...             NaN
# 17181  Use caution. Input from outdated and/or partia...             NaN
# 4233   Use caution. Input from outdated and/or partia...             NaN
# 8629   Use caution. Input from outdated and/or partia...             NaN
# 13025  Use caution. Input from outdated and/or partia...             NaN
# 16564  Use caution. Input from outdated and/or partia...             NaN
# 3507   Use caution. Input from outdated and/or partia...             NaN
# 7903   Use caution. Input from outdated and/or partia...             NaN
# 12299  Use caution. Input from outdated and/or partia...             NaN
# 17218  Use caution. Input from outdated and/or partia...             NaN
# 4211   Use caution. Input from outdated and/or partia...             NaN
# 8607   Use caution. Input from outdated and/or partia...             NaN
# 13003  Use caution. Input from outdated and/or partia...             NaN
#
#        closing_year closing_date  ...  Long_term_liabilities_Equity_ratio  \
# 16565        2024.0   2024-11-26  ...                                 NaN
# 3508         2024.0   2024-11-26  ...                                 NaN
# 7904         2024.0   2024-11-26  ...                                 NaN
# 12300        2024.0   2024-11-26  ...                                 NaN
# 17219           NaN          NaN  ...                                 NaN
# 4212            NaN          NaN  ...                                 NaN
# 8608            NaN          NaN  ...                                 NaN
# 13004           NaN          NaN  ...                                 NaN
# 17181           NaN          NaN  ...                                 NaN
# 4233            NaN          NaN  ...                                 NaN
# 8629            NaN          NaN  ...                                 NaN
# 13025           NaN          NaN  ...                                 NaN
# 16564        2025.0   2025-03-04  ...                                 NaN
# 3507         2025.0   2025-03-04  ...                                 NaN
# 7903         2025.0   2025-03-04  ...                                 NaN
# 12299        2025.0   2025-03-04  ...                                 NaN
# 17218           NaN          NaN  ...                                 NaN
# 4211            NaN          NaN  ...                                 NaN
# 8607            NaN          NaN  ...                                 NaN
# 13003           NaN          NaN  ...                                 NaN
#
#        Short_term_liabilities_Equity_ratio  Interest_coverage_ratio  \
# 16565                                  NaN                      NaN
# 3508                                   NaN                      NaN
# 7904                                   NaN                      NaN
# 12300                                  NaN                      NaN
# 17219                                  NaN                      NaN
# 4212                                   NaN                      NaN
# 8608                                   NaN                      NaN
# 13004                                  NaN                      NaN
# 17181                                  NaN                      NaN
# 4233                                   NaN                      NaN
# 8629                                   NaN                      NaN
# 13025                                  NaN                      NaN
# 16564                                  NaN                      NaN
# 3507                                   NaN                      NaN
# 7903                                   NaN                      NaN
# 12299                                  NaN                      NaN
# 17218                                  NaN                      NaN
# 4211                                   NaN                      NaN
# 8607                                   NaN                      NaN
# 13003                                  NaN                      NaN
#
#        Solvency_ratio_Asset_based  Debt_Asset_ratio  ROE_using_Net_income  \
# 16565                         NaN               NaN                   NaN
# 3508                          NaN               NaN                   NaN
# 7904                          NaN               NaN                   NaN
# 12300                         NaN               NaN                   NaN
# 17219                         NaN               NaN                   NaN
# 4212                          NaN               NaN                   NaN
# 8608                          NaN               NaN                   NaN
# 13004                         NaN               NaN                   NaN
# 17181                         NaN               NaN                   NaN
# 4233                          NaN               NaN                   NaN
# 8629                          NaN               NaN                   NaN
# 13025                         NaN               NaN                   NaN
# 16564                         NaN               NaN                   NaN
# 3507                          NaN               NaN                   NaN
# 7903                          NaN               NaN                   NaN
# 12299                         NaN               NaN                   NaN
# 17218                         NaN               NaN                   NaN
# 4211                          NaN               NaN                   NaN
# 8607                          NaN               NaN                   NaN
# 13003                         NaN               NaN                   NaN
#
#        ROA_using_Net_income  Net_assets_turnover  Number_of_employees  \
# 16565                   NaN                  NaN                  NaN
# 3508                    NaN                  NaN                  NaN
# 7904                    NaN                  NaN                  NaN
# 12300                   NaN                  NaN                  NaN
# 17219                   NaN                  NaN                  NaN
# 4212                    NaN                  NaN                  NaN
# 8608                    NaN                  NaN                  NaN
# 13004                   NaN                  NaN                  NaN
# 17181                   NaN                  NaN                  NaN
# 4233                    NaN                  NaN                  NaN
# 8629                    NaN                  NaN                  NaN
# 13025                   NaN                  NaN                  NaN
# 16564                   NaN                  NaN                  NaN
# 3507                    NaN                  NaN                  NaN
# 7903                    NaN                  NaN                  NaN
# 12299                   NaN                  NaN                  NaN
# 17218                   NaN                  NaN                  NaN
# 4211                    NaN                  NaN                  NaN
# 8607                    NaN                  NaN                  NaN
# 13003                   NaN                  NaN                  NaN
#
#                          created_at_utc
# 16565  2026-03-05 09:02:26.421112+00:00
# 3508   2026-03-12 11:47:28.083189+00:00
# 7904   2026-03-12 12:03:33.903081+00:00
# 12300  2026-03-12 15:07:22.230528+00:00
# 17219  2026-03-05 09:02:26.421112+00:00
# 4212   2026-03-12 11:47:28.083189+00:00
# 8608   2026-03-12 12:03:33.903081+00:00
# 13004  2026-03-12 15:07:22.230528+00:00
# 17181  2026-03-05 09:02:26.421112+00:00
# 4233   2026-03-12 11:47:28.083189+00:00
# 8629   2026-03-12 12:03:33.903081+00:00
# 13025  2026-03-12 15:07:22.230528+00:00
# 16564  2026-03-05 09:02:26.421112+00:00
# 3507   2026-03-12 11:47:28.083189+00:00
# 7903   2026-03-12 12:03:33.903081+00:00
# 12299  2026-03-12 15:07:22.230528+00:00
# 17218  2026-03-05 09:02:26.421112+00:00
# 4211   2026-03-12 11:47:28.083189+00:00
# 8607   2026-03-12 12:03:33.903081+00:00
# 13003  2026-03-12 15:07:22.230528+00:00
#
# [20 rows x 52 columns]

# %% [markdown]
# ## Preparing the financial history table
#
# The financial history table contains multiple records for the same company and closing year.
# These repeated rows reflect multiple technical assessment snapshots over time, captured by `created_at_utc`.
#
# For the thesis pipeline, the required structure is:
#
# **one row = one company in one year**
#
# Therefore, the table is cleaned by keeping only the **latest available record** for each combination of:
#
# - `moodys_bvd_id`
# - `closing_year`
#
# This preserves the yearly financial history while removing repeated technical snapshots.
#
# The cleaned table will later be joined to the supplier bridge and the contract-year dataset using:
#
# - `moodys_bvd_id`
# - `year`

# %%
# Work on a copy
df_financials_clean = df_financials.copy()

# Clean key column
df_financials_clean["moodys_bvd_id"] = (
    df_financials_clean["moodys_bvd_id"]
    .astype("string")
    .str.strip()
)

# Parse timestamps
df_financials_clean["created_at_utc"] = pd.to_datetime(
    df_financials_clean["created_at_utc"],
    errors="coerce"
)

df_financials_clean["closing_date"] = pd.to_datetime(
    df_financials_clean["closing_date"],
    errors="coerce"
)

# Remove rows without company id or closing year
df_financials_clean = df_financials_clean[
    df_financials_clean["moodys_bvd_id"].notna() &
    df_financials_clean["closing_year"].notna()
].copy()

# Keep the latest record per company-year
df_financials_clean = (
    df_financials_clean
    .sort_values("created_at_utc")
    .drop_duplicates(
        subset=["moodys_bvd_id", "closing_year"],
        keep="last"
    )
    .copy()
)

# Standardize year column
df_financials_clean["year"] = (
    pd.to_numeric(df_financials_clean["closing_year"], errors="coerce")
    .astype("Int64")
)

# Reorder columns for readability
front_cols = [
    "moodys_bvd_id",
    "moodys_company_name",
    "year",
    "closing_year",
    "closing_date",
    "created_at_utc",
    "Status",
    "Implied_rating",
    "risk_level",
    "Financial_level",
    "output_text",
]

remaining_cols = [col for col in df_financials_clean.columns if col not in front_cols]
df_financials_clean = df_financials_clean[front_cols + remaining_cols]

# Checks
print("Original financial history shape:", df_financials.shape)
print("Clean financial history shape:", df_financials_clean.shape)

print("\nDuplicate company-year rows:",
      df_financials_clean.duplicated(["moodys_bvd_id", "year"]).sum())

print("\nUnique companies:",
      df_financials_clean["moodys_bvd_id"].nunique())

print("\nYear range:")
print(df_financials_clean["year"].min(), "to", df_financials_clean["year"].max())

df_financials_clean.head()
# Out:
# Original financial history shape: (17390, 52)
# Clean financial history shape: (3529, 53)
#
# Duplicate company-year rows: 0
#
# Unique companies: 1241
#
# Year range:
# 1997 to 2026
#       moodys_bvd_id            moodys_company_name  year  closing_year  \
# 14391    GB02490104                 Bio-Techne LTD  2022        2022.0
# 14050  DE2110000553                   Sartorius AG  2022        2022.0
# 14201     LULB25789                 SanisSure S.A.  2021        2021.0
# 14532  DE7130049291    Amcor Flexibles Singen GmbH  2022        2022.0
# 14589    LULB186284  Amazon Web Services EMEA SARL  2022        2022.0
#
#       closing_date                   created_at_utc  Status Implied_rating  \
# 14391   2022-06-30 2026-03-05 09:02:26.421112+00:00  Active            Baa
# 14050   2022-12-31 2026-03-05 09:02:26.421112+00:00  Active              A
# 14201   2021-12-31 2026-03-05 09:02:26.421112+00:00  Active            Baa
# 14532   2022-06-30 2026-03-05 09:02:26.421112+00:00  Active             Ba
# 14589   2022-12-31 2026-03-05 09:02:26.421112+00:00  Active            Baa
#
#          risk_level     Financial_level  ... Total_liabilities_Equity_ratio  \
# 14391  Take caution                 NaN  ...                      31.132483
# 14050      Go ahead  Low financial risk  ...                     162.428072
# 14201  Take caution                 NaN  ...                     272.158195
# 14532  Take caution                 NaN  ...                     383.633361
# 14589      Go ahead  Low financial risk  ...                     236.155083
#
#       Long_term_liabilities_Equity_ratio  Short_term_liabilities_Equity_ratio  \
# 14391                           1.348341                            29.784142
# 14050                          94.603031                            67.825040
# 14201                         237.538807                            34.619388
# 14532                          73.990382                           309.642979
# 14589                           0.831076                           235.324008
#
#        Interest_coverage_ratio  Solvency_ratio_Asset_based  Debt_Asset_ratio  \
# 14391                42.079646                      76.259          0.195834
# 14050                16.307692                      38.106          0.359717
# 14201                      NaN                      26.870          0.000000
# 14532                 9.423212                      20.677          0.000000
# 14589                 0.812609                      29.748          0.000000
#
#        ROE_using_Net_income  ROA_using_Net_income  Net_assets_turnover  \
# 14391                29.641                22.604                0.919
# 14050                23.651                 9.013                0.811
# 14201                   NaN                   NaN                  NaN
# 14532                   NaN                   NaN                4.936
# 14589                22.206                 6.606                8.358
#
#        Number_of_employees
# 14391                150.0
# 14050              15942.0
# 14201                  NaN
# 14532               1242.0
# 14589                  NaN
#
# [5 rows x 53 columns]

# %%
df_financials_clean.duplicated(["moodys_bvd_id", "year"]).sum()
# Out:
# np.int64(0)

# %% [markdown]
# Let's look for one example...

# %%
company_id = "GB03898252"

raw_company = (
    df_financials[
        df_financials["moodys_bvd_id"] == company_id
    ]
    .sort_values(["closing_year", "created_at_utc"])
)

raw_company[
    [
        "moodys_bvd_id",
        "moodys_company_name",
        "closing_year",
        "created_at_utc",
        "Status",
        "Implied_rating",
        "risk_level",
        "Financial_level",
        "output_text"
    ]
]
# Out:
#       moodys_bvd_id        moodys_company_name  closing_year  \
# 13208    GB03898252  THE Turner Agency Limited        2023.0
# 14199    GB03898252  THE Turner Agency Limited        2023.0
# 0        GB03898252  THE Turner Agency Limited        2023.0
# 108      GB03898252  THE Turner Agency Limited        2023.0
# 4396     GB03898252  THE Turner Agency Limited        2023.0
# 4504     GB03898252  THE Turner Agency Limited        2023.0
# 8792     GB03898252  THE Turner Agency Limited        2023.0
# 8900     GB03898252  THE Turner Agency Limited        2023.0
# 14191    GB03898252  THE Turner Agency Limited        2024.0
# 118      GB03898252  THE Turner Agency Limited        2024.0
# 4514     GB03898252  THE Turner Agency Limited        2024.0
# 8910     GB03898252  THE Turner Agency Limited        2024.0
#
#                          created_at_utc  Status Implied_rating    risk_level  \
# 13208  2026-03-05 09:02:26.421112+00:00  Active             Ba  Take caution
# 14199  2026-03-05 09:02:26.421112+00:00  Active             Ba  Take caution
# 0      2026-03-12 11:47:28.083189+00:00  Active             Ba  Take caution
# 108    2026-03-12 11:47:28.083189+00:00  Active             Ba  Take caution
# 4396   2026-03-12 12:03:33.903081+00:00  Active             Ba  Take caution
# 4504   2026-03-12 12:03:33.903081+00:00  Active             Ba  Take caution
# 8792   2026-03-12 15:07:22.230528+00:00  Active             Ba  Take caution
# 8900   2026-03-12 15:07:22.230528+00:00  Active             Ba  Take caution
# 14191  2026-03-05 09:02:26.421112+00:00  Active             Ba  Take caution
# 118    2026-03-12 11:47:28.083189+00:00  Active             Ba  Take caution
# 4514   2026-03-12 12:03:33.903081+00:00  Active             Ba  Take caution
# 8910   2026-03-12 15:07:22.230528+00:00  Active             Ba  Take caution
#
#       Financial_level                                        output_text
# 13208             NaN  Use caution. Input from outdated and/or partia...
# 14199             NaN  Use caution. Input from outdated and/or partia...
# 0                 NaN  Use caution. Input from outdated and/or partia...
# 108               NaN  Use caution. Input from outdated and/or partia...
# 4396              NaN  Use caution. Input from outdated and/or partia...
# 4504              NaN  Use caution. Input from outdated and/or partia...
# 8792              NaN  Use caution. Input from outdated and/or partia...
# 8900              NaN  Use caution. Input from outdated and/or partia...
# 14191             NaN  Use caution. Input from outdated and/or partia...
# 118               NaN  Use caution. Input from outdated and/or partia...
# 4514              NaN  Use caution. Input from outdated and/or partia...
# 8910              NaN  Use caution. Input from outdated and/or partia...

# %%
clean_company = (
    df_financials_clean[
        df_financials_clean["moodys_bvd_id"] == company_id
    ]
    .sort_values(["year", "created_at_utc"])
)

clean_company[
    [
        "moodys_bvd_id",
        "moodys_company_name",
        "year",
        "created_at_utc",
        "Status",
        "Implied_rating",
        "risk_level",
        "Financial_level",
        "output_text"
    ]
]
# Out:
#      moodys_bvd_id        moodys_company_name  year  \
# 8900    GB03898252  THE Turner Agency Limited  2023
# 8910    GB03898252  THE Turner Agency Limited  2024
#
#                        created_at_utc  Status Implied_rating    risk_level  \
# 8900 2026-03-12 15:07:22.230528+00:00  Active             Ba  Take caution
# 8910 2026-03-12 15:07:22.230528+00:00  Active             Ba  Take caution
#
#      Financial_level                                        output_text
# 8900             NaN  Use caution. Input from outdated and/or partia...
# 8910             NaN  Use caution. Input from outdated and/or partia...

# %%
print("Raw rows per year:")
print(raw_company["closing_year"].value_counts().sort_index())

print("\nClean rows per year:")
print(clean_company["year"].value_counts().sort_index())
# Out:
# Raw rows per year:
# closing_year
# 2023.0    8
# 2024.0    4
# Name: count, dtype: int64
#
# Clean rows per year:
# year
# 2023    1
# 2024    1
# Name: count, dtype: Int64

# %%
df_financials_clean = df_financials_clean.rename(
    columns={"year": "Join_Year"}
)

df_financials_clean["Join_Year"] = pd.to_numeric(
    df_financials_clean["Join_Year"],
    errors="coerce"
).astype("Int64")

# %%
df_financials_clean.head()
# Out:
#       moodys_bvd_id            moodys_company_name  Join_Year  closing_year  \
# 14391    GB02490104                 Bio-Techne LTD       2022        2022.0
# 14050  DE2110000553                   Sartorius AG       2022        2022.0
# 14201     LULB25789                 SanisSure S.A.       2021        2021.0
# 14532  DE7130049291    Amcor Flexibles Singen GmbH       2022        2022.0
# 14589    LULB186284  Amazon Web Services EMEA SARL       2022        2022.0
#
#       closing_date                   created_at_utc  Status Implied_rating  \
# 14391   2022-06-30 2026-03-05 09:02:26.421112+00:00  Active            Baa
# 14050   2022-12-31 2026-03-05 09:02:26.421112+00:00  Active              A
# 14201   2021-12-31 2026-03-05 09:02:26.421112+00:00  Active            Baa
# 14532   2022-06-30 2026-03-05 09:02:26.421112+00:00  Active             Ba
# 14589   2022-12-31 2026-03-05 09:02:26.421112+00:00  Active            Baa
#
#          risk_level     Financial_level  ... Total_liabilities_Equity_ratio  \
# 14391  Take caution                 NaN  ...                      31.132483
# 14050      Go ahead  Low financial risk  ...                     162.428072
# 14201  Take caution                 NaN  ...                     272.158195
# 14532  Take caution                 NaN  ...                     383.633361
# 14589      Go ahead  Low financial risk  ...                     236.155083
#
#       Long_term_liabilities_Equity_ratio  Short_term_liabilities_Equity_ratio  \
# 14391                           1.348341                            29.784142
# 14050                          94.603031                            67.825040
# 14201                         237.538807                            34.619388
# 14532                          73.990382                           309.642979
# 14589                           0.831076                           235.324008
#
#        Interest_coverage_ratio  Solvency_ratio_Asset_based  Debt_Asset_ratio  \
# 14391                42.079646                      76.259          0.195834
# 14050                16.307692                      38.106          0.359717
# 14201                      NaN                      26.870          0.000000
# 14532                 9.423212                      20.677          0.000000
# 14589                 0.812609                      29.748          0.000000
#
#        ROE_using_Net_income  ROA_using_Net_income  Net_assets_turnover  \
# 14391                29.641                22.604                0.919
# 14050                23.651                 9.013                0.811
# 14201                   NaN                   NaN                  NaN
# 14532                   NaN                   NaN                4.936
# 14589                22.206                 6.606                8.358
#
#        Number_of_employees
# 14391                150.0
# 14050              15942.0
# 14201                  NaN
# 14532               1242.0
# 14589                  NaN
#
# [5 rows x 53 columns]

# %%
print(
    "Duplicate company-year:",
    df_financials_clean.duplicated(
        ["moodys_bvd_id", "Join_Year"]
    ).sum()
)
# Out:
# Duplicate company-year: 0

# %%
df_financials_clean.to_csv(
    "tables/joining/financials_clean.csv",
    index=False
)
